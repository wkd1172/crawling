# %%
import requests,os
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
### 날짜를 좀 더 정확하게 파악하기 위해서 #Lib datatime 을 쓴다.
from datetime import date

# %%
url_main = "http://bbs1.agora.media.daum.net/gaia/do/debate/list?"
params = "pageIndex=3000&bbsId=D102"
url_test = "http://bbs1.agora.media.daum.net/gaia/do/debate/list?pageIndex=3000&bbsId=D102"

# %%
response_1 = requests.get(url_test)
response_1.status_code
# Out:
# 200

# %%
html_1 = response_1.text
soup_1 = BeautifulSoup(html_1,"html.parser")
soup_1
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=10" http-equiv="X-UA-Compatible">
# <title>교육 |  Daum 아고라</title>
# <meta content="교육 | Daum 아고라" name="dcterms.title"/>
# <meta content=" - Daum 아고라" name="title"/>
# <meta content=" - Daum 아고라" property="og:title"/>
# <meta content="" name="description"/>
# <meta content="" property="og:description">
# <link href="http://i1.daumcdn.net/uf/image/U01/agora/53FADD655034C0002D" rel="image_src"/>
# <meta content="http://i1.daumcdn.net/img-media/mobile/meta/agora.png" property="og:image"/>
# <meta content="article" property="og:type"/>
# <meta content="미디어다음, 미디어Daum, media, 미디어, 뉴스, news, 신문, 인터넷신문, 사이버신문, 최신뉴스, 정치, 사회, 문화, 생활, 방송, 연예, 국제, 디지털, 미디어, 오피니언, 사설, 칼럼, 속보, 기획, 특집, 취재, 이슈, 포커스, 인물, 기사, 많이본, 깜짝, 감동, 핫이슈토론, 토론, 논객, 명예의 전당, 즉석투표, 다음생각, 인터뷰, 다음리포터, 네티즌 토론방, 게시판, 포토, 포토갤러리, TV뉴스, 동영상뉴스, 연재, 잡지, 오늘, 데일리, 소설, 만화, 만화가, 만평, 만화속세상, 날씨" name="keywords"/>
# ...

# %%
for tag in soup_1.select(".gLlist tr"):
    try: 
        date_1 = tag.find("td",class_="gLdate").text
        print(date_1)
    except AttributeError:
        pass
# Out:
# 16.01.19
# 16.01.19
# 16.01.19
# 16.01.19
# 16.01.19
# 16.01.19
# 16.01.19
# 16.01.19
# 16.01.19
# 16.01.19
# 16.01.19
# 16.01.19
# 16.01.19
# 16.01.19
# 16.01.19
# 16.01.19
# 16.01.19
# 16.01.19
# 16.01.19
# 16.01.19

# %%
#params = "pageIndex=3000&bbsId=D102"
page = int(3100)
while data_2 != "17.01.01":
    page + = 
    params = {
        "pageIndex" : page,
        "bbsId" : "D102"
    }
    response = requests.get(url_main,params=params)
    html = response.text
    soup = BeautifulSoup(html,"html.parser")
    for tag in soup.select(".gLlist tr"):
        date_2
# Out:
#   File "<ipython-input-6-17e969f0226b>", line 4
#     page + =
#            ^
# SyntaxError: invalid syntax
